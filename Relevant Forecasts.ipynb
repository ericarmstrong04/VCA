# %%
import os
import pandas as pd
from prophet import Prophet
from matplotlib.backends.backend_pdf import PdfPages

os.chdir(os.path.expanduser("/Users/ericarmstrong/Desktop"))

df = pd.read_csv("econ_data v3.csv")
df.head()

df.rename(columns={"date": "ds", "data": "y"}, inplace=True)
# Convert date column to datetime format if needed
df["ds"] = pd.to_datetime(df["ds"])
subdfs = {name: group for name, group in df.groupby('seriesName')}
# Out:
# /Users/ericarmstrong/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/ericarmstrong/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
m1 = Prophet()
m1.fit(subdfs["NRSI511N"])

future1 = m1.make_future_dataframe(periods=365)
print(future1.tail())

forecast1 = m1.predict(future1)
print(forecast1[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig1 = m1.plot(forecast1)
fig2 = m1.plot_components(forecast1)
# Out:
# 13:32:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:35 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 652 2026-03-28
# 653 2026-03-29
# 654 2026-03-30
# 655 2026-03-31
# 656 2026-04-01
#             ds          yhat    yhat_lower    yhat_upper
# 652 2026-03-28  79843.780527  78346.363831  81297.353264
# 653 2026-03-29  78929.167015  77371.991267  80505.986193
# 654 2026-03-30  78066.789994  76524.021472  79610.081196
# 655 2026-03-31  77265.585936  75685.260293  78808.870742
# 656 2026-04-01  76532.838960  74987.105562  78145.990804

# %%
m2 = Prophet()
m2.fit(subdfs["NRSV2N"])

future2 = m2.make_future_dataframe(periods=365)
print(future2.tail())

forecast2 = m2.predict(future2)
print(forecast2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig3 = m2.plot(forecast2)
fig4 = m2.plot_components(forecast2)
# Out:
# 13:32:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:36 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 761 2026-04-27
# 762 2026-04-28
# 763 2026-04-29
# 764 2026-04-30
# 765 2026-05-01
#             ds           yhat     yhat_lower     yhat_upper
# 761 2026-04-27  105144.294705  100541.880453  109569.336303
# 762 2026-04-28  105095.718592  100729.186293  110463.115628
# 763 2026-04-29  104963.204453  100029.393828  109408.994669
# 764 2026-04-30  104752.221067  100158.251580  109700.617014
# 765 2026-05-01  104470.117526   99350.482614  108832.145776

# %%
m3 = Prophet()
m3.fit(subdfs["ERSI5N"])

future3 = m3.make_future_dataframe(periods=90)
print(future3.tail())

forecast3 = m3.predict(future3)
print(forecast3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig5 = m3.plot(forecast3)
fig6 = m3.plot_components(forecast3)
# Out:
# 13:32:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:37 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 114 2025-03-28
# 115 2025-03-29
# 116 2025-03-30
# 117 2025-03-31
# 118 2025-04-01
#             ds          yhat   yhat_lower    yhat_upper
# 114 2025-03-28  -1379.265682 -2683.807331   -168.379032
# 115 2025-03-29   1880.904970   719.767969   3242.922565
# 116 2025-03-30   5014.294655  3782.127161   6233.260465
# 117 2025-03-31   7946.689870  6775.190067   9218.416111
# 118 2025-04-01  10610.606748  9384.031835  11772.493483

# %%
m4 = Prophet()
m4.fit(subdfs["PMEA"])

future4 = m4.make_future_dataframe(periods=365)
print(future4.tail())

forecast4 = m4.predict(future4)
print(forecast4[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig7 = m4.plot(forecast4)
fig8 = m4.plot_components(forecast4)
# Out:
# 13:32:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:37 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 873 2026-04-27
# 874 2026-04-28
# 875 2026-04-29
# 876 2026-04-30
# 877 2026-05-01
#             ds        yhat  yhat_lower  yhat_upper
# 873 2026-04-27  150.098535  143.786639  156.536772
# 874 2026-04-28  149.435709  143.429809  155.523761
# 875 2026-04-29  148.715123  142.823760  154.569963
# 876 2026-04-30  147.952581  142.001557  153.645990
# 877 2026-05-01  147.164761  140.619065  153.153540

# %%
m5 = Prophet()
m5.fit(subdfs["PXEA"])

future5 = m5.make_future_dataframe(periods=365)
print(future5.tail())

forecast5 = m5.predict(future5)
print(forecast5[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig9 = m5.plot(forecast5)
fig0 = m5.plot_components(forecast5)
# Out:
# 13:32:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:38 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 861 2026-04-27
# 862 2026-04-28
# 863 2026-04-29
# 864 2026-04-30
# 865 2026-05-01
#             ds        yhat  yhat_lower  yhat_upper
# 861 2026-04-27  163.005454  157.738092  168.653443
# 862 2026-04-28  162.771503  157.845259  168.228473
# 863 2026-04-29  162.364130  157.351620  167.500524
# 864 2026-04-30  161.789480  157.003394  166.951305
# 865 2026-05-01  161.058517  155.481898  165.803131

# %%
# Some things to think about in relation to tariffs
# Import and Export Forecasts
# Steel tariff took effect in 2018, the decline is clearly present in the graph however the bounceback growth when the tariff was lifted far exceeded
# the dropoff.
# Same exact tariff is being put back into place; dampening effect might be stronger since tariff is scaled by 2, but if the series follows history,
# we should expect a growth.
