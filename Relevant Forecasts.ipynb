# %%
import os
import pandas as pd
from prophet import Prophet
from matplotlib.backends.backend_pdf import PdfPages

os.chdir(os.path.expanduser("/Users/ericarmstrong/Desktop"))

df = pd.read_csv("table_final.csv")
df.head()

df.rename(columns={"date": "ds", "data": "y"}, inplace=True)
# Convert date column to datetime format if needed
df["ds"] = pd.to_datetime(df["ds"])
subdfs = {name: group for name, group in df.groupby('seriesName')}

# %%
m1 = Prophet()
m1.fit(subdfs["NRSI511N"])

future1 = m1.make_future_dataframe(periods=365)
print(future1.tail())

forecast1 = m1.predict(future1)
print(forecast1[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig1 = m1.plot(forecast1)
fig2 = m1.plot_components(forecast1)
# Out:
# 10:48:02 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:02 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 652 2026-03-28
# 653 2026-03-29
# 654 2026-03-30
# 655 2026-03-31
# 656 2026-04-01
#             ds          yhat    yhat_lower    yhat_upper
# 652 2026-03-28  79843.780527  78356.705688  81440.732029
# 653 2026-03-29  78929.167015  77551.337540  80405.266228
# 654 2026-03-30  78066.789994  76493.666901  79570.026976
# 655 2026-03-31  77265.585936  75743.189239  78860.088361
# 656 2026-04-01  76532.838960  75020.050314  78005.456231

# %%
m2 = Prophet()
m2.fit(subdfs["NRSV2N"])

future2 = m2.make_future_dataframe(periods=365)
print(future2.tail())

forecast2 = m2.predict(future2)
print(forecast2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig3 = m2.plot(forecast2)
fig4 = m2.plot_components(forecast2)
# Out:
# 10:48:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:03 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 761 2026-04-27
# 762 2026-04-28
# 763 2026-04-29
# 764 2026-04-30
# 765 2026-05-01
#             ds           yhat     yhat_lower     yhat_upper
# 761 2026-04-27  105144.294705  100766.814603  109516.333337
# 762 2026-04-28  105095.718592  100573.680097  109586.697326
# 763 2026-04-29  104963.204453  100583.498522  109749.831719
# 764 2026-04-30  104752.221067  100200.503463  109149.905040
# 765 2026-05-01  104470.117526   99880.175582  109447.758609

# %%
m3 = Prophet()
m3.fit(subdfs["CCIN"])

future3 = m3.make_future_dataframe(periods=90)
print(future3.tail())

forecast3 = m3.predict(future3)
print(forecast3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig5 = m3.plot(forecast3)
fig6 = m3.plot_components(forecast3)
# Out:
# 10:48:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:04 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 786 2025-08-26
# 787 2025-08-27
# 788 2025-08-28
# 789 2025-08-29
# 790 2025-08-30
#             ds        yhat  yhat_lower  yhat_upper
# 786 2025-08-26  122.821289   95.139497  151.298292
# 787 2025-08-27  121.334883   93.882900  149.043149
# 788 2025-08-28  119.648762   91.982811  148.131053
# 789 2025-08-29  117.770443   92.959882  146.967931
# 790 2025-08-30  115.711443   87.367787  142.776565

# %%
m4 = Prophet()
m4.fit(subdfs["PMEA"])

future4 = m4.make_future_dataframe(periods=365)
print(future4.tail())

forecast4 = m4.predict(future4)
print(forecast4[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig7 = m4.plot(forecast4)
fig8 = m4.plot_components(forecast4)
# Out:
# 10:48:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:04 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 873 2026-04-27
# 874 2026-04-28
# 875 2026-04-29
# 876 2026-04-30
# 877 2026-05-01
#             ds        yhat  yhat_lower  yhat_upper
# 873 2026-04-27  150.098535  143.835160  155.735037
# 874 2026-04-28  149.435709  143.772099  155.561410
# 875 2026-04-29  148.715123  142.621999  154.610914
# 876 2026-04-30  147.952581  141.584644  154.437878
# 877 2026-05-01  147.164761  141.073969  153.309906

# %%
m5 = Prophet()
m5.fit(subdfs["PXEA"])

future5 = m5.make_future_dataframe(periods=365)
print(future5.tail())

forecast5 = m5.predict(future5)
print(forecast5[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig9 = m5.plot(forecast5)
fig10 = m5.plot_components(forecast5)
# Out:
# 10:48:05 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:05 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 861 2026-04-27
# 862 2026-04-28
# 863 2026-04-29
# 864 2026-04-30
# 865 2026-05-01
#             ds        yhat  yhat_lower  yhat_upper
# 861 2026-04-27  163.005454  157.757781  168.045819
# 862 2026-04-28  162.771503  157.512325  167.442767
# 863 2026-04-29  162.364130  156.555876  167.738923
# 864 2026-04-30  161.789480  156.651263  167.094656
# 865 2026-05-01  161.058517  155.493093  166.435422

# %%
m6 = Prophet()
m6.fit(subdfs["UFMEN"])

future6 = m6.make_future_dataframe(periods=365)
print(future6.tail())

forecast6 = m6.predict(future6)
print(forecast6[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig11 = m6.plot(forecast6)
fig12 = m6.plot_components(forecast6)
# Out:
# 10:48:06 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:06 - cmdstanpy - INFO - Chain [1] done processing
#              ds
# 1445 2026-04-27
# 1446 2026-04-28
# 1447 2026-04-29
# 1448 2026-04-30
# 1449 2026-05-01
#              ds        yhat  yhat_lower  yhat_upper
# 1445 2026-04-27  298.743290  272.506889  326.077545
# 1446 2026-04-28  298.112403  270.500840  327.146139
# 1447 2026-04-29  297.730186  269.151483  324.064325
# 1448 2026-04-30  297.608972  268.543580  327.766420
# 1449 2026-05-01  297.753731  269.101014  326.183710

# %%
m7 = Prophet()
m7.fit(subdfs["RECPROB"])

future7 = m7.make_future_dataframe(periods=365)
print(future7.tail())

forecast7 = m7.predict(future7)
print(forecast7[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig13 = m7.plot(forecast7)
fig14 = m7.plot_components(forecast7)
# Out:
# 10:48:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:07 - cmdstanpy - INFO - Chain [1] done processing
#              ds
# 1158 2026-05-28
# 1159 2026-05-29
# 1160 2026-05-30
# 1161 2026-05-31
# 1162 2026-06-01
#              ds       yhat  yhat_lower  yhat_upper
# 1158 2026-05-28  26.092759    5.508077   48.394260
# 1159 2026-05-29  26.330670    4.533127   47.886354
# 1160 2026-05-30  26.499291    6.284885   47.192500
# 1161 2026-05-31  26.597354    5.613519   46.614332
# 1162 2026-06-01  26.625687    6.200954   47.687425

# %%
m8 = Prophet()
m8.fit(subdfs["Personal consumption expenditures (PCE)"])

future8 = m8.make_future_dataframe(periods=365)
print(future8.tail())

forecast8 = m8.predict(future8)
print(forecast8[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())

fig15 = m8.plot(forecast8)
fig16 = m8.plot_components(forecast8)
# Out:
# 10:52:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:52:24 - cmdstanpy - INFO - Chain [1] done processing
#             ds
# 545 2026-04-27
# 546 2026-04-28
# 547 2026-04-29
# 548 2026-04-30
# 549 2026-05-01
#             ds          yhat    yhat_lower    yhat_upper
# 545 2026-04-27  1.673353e+07  1.647702e+07  1.700071e+07
# 546 2026-04-28  1.678207e+07  1.652081e+07  1.705290e+07
# 547 2026-04-29  1.680749e+07  1.655042e+07  1.708565e+07
# 548 2026-04-30  1.680949e+07  1.655275e+07  1.708133e+07
# 549 2026-05-01  1.678844e+07  1.652817e+07  1.706503e+07

# %%
# Some things to think about in relation to tariffs
# Import and Export Forecasts
# Steel tariff took effect in 2018, the decline is clearly present in the graph however the bounceback growth when the tariff was lifted far exceeded
# the dropoff.
# Same exact tariff is being put back into place; dampening effect might be stronger since tariff is scaled by 2, but if the series follows history,
# we should expect a growth.
